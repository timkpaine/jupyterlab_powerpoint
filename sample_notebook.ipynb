# %% [markdown]
# # Test Title

# %% [markdown]
# ## Test Subtitle

# %%
# sample ignore
import lantern as l
df = l.line()

# %% [markdown]
# # Test Title 2

# %% [markdown]
# - Test
# - section
# - with
# - text

# %%
# test chart
df.plot();
